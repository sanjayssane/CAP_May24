# %%
import pandas as pd 
import numpy as np 
import os
os.chdir("C:/Training/Academy/Statistics (Python)/Datasets")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.array([2, 4, 5, 6, 7, 10, 11, 17])
b = np.array([23, 35, 45, 57, 68, 75, 84, 94])

# %%
np.cov(a, b, ddof=0)
# Out:
# array([[ 19.9375  ,  96.65625 ],
#        [ 96.65625 , 531.109375]])

# %%
np.var(a), np.var(b)
# Out:
# (19.9375, 531.109375)

# %%
plt.scatter(a, b)
plt.show()

# %%
a = np.array([2, 4, 5, 6, 7, 10, 11, 17])
b = np.array([95, 87, 82, 75, 66, 54, 44, 33])
np.cov(a, b, ddof=0)
# Out:
# array([[ 19.9375, -88.625 ],
#        [-88.625 , 416.    ]])

# %%
plt.scatter(a, b)
plt.show()

# %%
exp_sals = pd.read_csv("Exp_Salaries.csv")
exp_sals.head()
# Out:
#    Salary  Years_Previous_Experience  Years Employed  Years_Education  Gender  \
# 0   32782                          1               0                7    Male
# 1   32920                          3              15                9  Female
# 2   29548                          6               5                1    Male
# 3   39828                          6              18                5  Female
# 4   31528                         11               3                3    Male
#
#   Department  Number_Supervised
# 0          A                  0
# 1          A                  4
# 2          A                  0
# 3          A                  5
# 4          A                  6

# %%
sns.scatterplot(data=exp_sals, x='Years_Education', y='Salary')
plt.show()

# %% [markdown]
# Correlation

# %%
a = np.array([2, 4, 5, 6, 7, 10, 11, 17])
b = -a

# %%
np.corrcoef(a,b)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
np.corrcoef(exp_sals['Years_Education'],exp_sals['Salary'])
# Out:
# array([[1.        , 0.77699111],
#        [0.77699111, 1.        ]])

# %%
exp_sals['Years_Education'].corr(exp_sals['Salary'])
# Out:
# 0.776991108070747

# %%
num_cols = exp_sals.columns[ exp_sals.dtypes!=object ]
num_cols
# Out:
# Index(['Salary', 'Years_Previous_Experience', 'Years Employed',
#        'Years_Education', 'Number_Supervised'],
#       dtype='object')

# %%
num_exp_sals = exp_sals[num_cols]
num

# %%
exp_sals.corr()
# Out:
# C:\Users\Sanjay Sane\AppData\Local\Temp\ipykernel_2112\2190900223.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   exp_sals.corr()
#                              Salary  Years_Previous_Experience  \
# Salary                     1.000000                   0.029354
# Years_Previous_Experience  0.029354                   1.000000
# Years Employed             0.765174                   0.031277
# Years_Education            0.776991                   0.080169
# Number_Supervised          0.523925                   0.216198
#
#                            Years Employed  Years_Education  Number_Supervised
# Salary                           0.765174         0.776991           0.523925
# Years_Previous_Experience        0.031277         0.080169           0.216198
# ...

# %%
sns.heatmap( exp_sals.corr(),cmap="YlGnBu",annot=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# C:\Users\Sanjay Sane\AppData\Local\Temp\ipykernel_2112\2631015691.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap( exp_sals.corr(),cmap="YlGnBu",annot=True)

# %%
sns.heatmap( exp_sals.corr(),annot=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# C:\Users\Sanjay Sane\AppData\Local\Temp\ipykernel_2112\3276399231.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap( exp_sals.corr(),annot=True)
